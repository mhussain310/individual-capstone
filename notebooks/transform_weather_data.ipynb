# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 500)

# %%
df_hourly = pd.read_csv('../data/test/hourly_historical_weather.csv')
df_daily = pd.read_csv('../data/test/daily_historical_weather.csv')
df_current = pd.read_csv('../data/test/current_weather.csv')

# %%
df_hourly
# Out:
#                          time        date  time_epoch  temp_c  temp_f  is_day  \
# 0     2024-12-24 00:00:00.000  2024-12-24  1735016400    -3.2    26.3       0
# 1     2024-12-24 01:00:00.000  2024-12-24  1735020000    -3.3    26.1       0
# 2     2024-12-24 02:00:00.000  2024-12-24  1735023600    -3.2    26.3       0
# 3     2024-12-24 03:00:00.000  2024-12-24  1735027200    -3.1    26.5       0
# 4     2024-12-24 04:00:00.000  2024-12-24  1735030800    -2.9    26.7       0
# ...                       ...         ...         ...     ...     ...     ...
# 2179  2024-11-23 19:00:00.000  2024-11-23  1732406400     7.1    44.8       0
# 2180  2024-11-23 20:00:00.000  2024-11-23  1732410000     7.1    44.8       0
# 2181  2024-11-23 21:00:00.000  2024-11-23  1732413600     7.2    45.0       0
# 2182  2024-11-23 22:00:00.000  2024-11-23  1732417200     6.7    44.1       0
# 2183  2024-11-23 23:00:00.000  2024-11-23  1732420800     6.9    44.4       0
#
# ...

# %%
df_hourly["time"] = pd.to_datetime(df_hourly["time"])
df_hourly["time"] = df_hourly["time"].dt.strftime("%Y-%m-%d %H:%M:%S")

# %%
df_hourly
# Out:
#                      time        date  time_epoch  temp_c  temp_f  is_day  \
# 0     2024-12-24 00:00:00  2024-12-24  1735016400    -3.2    26.3       0
# 1     2024-12-24 01:00:00  2024-12-24  1735020000    -3.3    26.1       0
# 2     2024-12-24 02:00:00  2024-12-24  1735023600    -3.2    26.3       0
# 3     2024-12-24 03:00:00  2024-12-24  1735027200    -3.1    26.5       0
# 4     2024-12-24 04:00:00  2024-12-24  1735030800    -2.9    26.7       0
# ...                   ...         ...         ...     ...     ...     ...
# 2179  2024-11-23 19:00:00  2024-11-23  1732406400     7.1    44.8       0
# 2180  2024-11-23 20:00:00  2024-11-23  1732410000     7.1    44.8       0
# 2181  2024-11-23 21:00:00  2024-11-23  1732413600     7.2    45.0       0
# 2182  2024-11-23 22:00:00  2024-11-23  1732417200     6.7    44.1       0
# 2183  2024-11-23 23:00:00  2024-11-23  1732420800     6.9    44.4       0
#
#       condition_text  condition_icon  condition_code  wind_mph  wind_kph  \
# ...

# %%
df_hourly.sort_values(by='date')
# Out:
#                          time        date  time_epoch  temp_c  temp_f  is_day  \
# 1486  2024-10-25 22:00:00.000  2024-10-25  1729908000    11.6    52.9       0
# 1485  2024-10-25 21:00:00.000  2024-10-25  1729904400    14.4    57.8       0
# 1484  2024-10-25 20:00:00.000  2024-10-25  1729900800    14.3    57.8       0
# 1483  2024-10-25 19:00:00.000  2024-10-25  1729897200    14.3    57.8       0
# 1482  2024-10-25 18:00:00.000  2024-10-25  1729893600    14.3    57.8       1
# ...                       ...         ...         ...     ...     ...     ...
# 721   2025-01-23 01:00:00.000  2025-01-23  1737612000    -8.0    17.5       0
# 720   2025-01-23 00:00:00.000  2025-01-23  1737608400    -7.8    18.0       0
# 743   2025-01-23 23:00:00.000  2025-01-23  1737691200    -5.6    21.9       0
# 730   2025-01-23 10:00:00.000  2025-01-23  1737644400    -6.3    20.7       1
# 742   2025-01-23 22:00:00.000  2025-01-23  1737687600    -5.9    21.3       0
#
# ...

# %%
df_daily.sort_values(by='date', ascending=False)
# Out:
#           date location_name location_region          location_country  \
# 30  2025-01-23      New York        New York  United States of America
# 29  2025-01-22      New York        New York  United States of America
# 28  2025-01-21      New York        New York  United States of America
# 27  2025-01-20      New York        New York  United States of America
# 26  2025-01-19      New York        New York  United States of America
# ..         ...           ...             ...                       ...
# 65  2024-10-29      New York        New York  United States of America
# 64  2024-10-28      New York        New York  United States of America
# 63  2024-10-27      New York        New York  United States of America
# 62  2024-10-26      New York        New York  United States of America
# 61  2024-10-25      New York        New York  United States of America
#
#     location_lat  location_lon    location_tz_id location_localtime  \
# ...
